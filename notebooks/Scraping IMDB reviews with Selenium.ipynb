# %% [markdown]
# # Scraping IMDB reviews with Selenium

# %% [markdown]
# Here I'll be using `selenium` to collect IMDB reviews for Star Wars: The Last Jedi

# %%
import os, re
import time

from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import WebDriverException

# %%
driver = webdriver.Chrome()
driver.get("http://www.imdb.com/title/tt2527336/reviews?ref_=tt_urv")

# %%
text_elements = driver.find_elements_by_xpath('//*[@id="main"]/section/div[2]/div[2]/div/div[1]/div[1]/div[4]/div[1]')

# %%
text_element = text_elements[0]
text_element
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="ad1220ade4419de158f967b3ca0b35b4", element="0.8578279281383991-2")>

# %%
text_element
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="ad1220ade4419de158f967b3ca0b35b4", element="0.8578279281383991-2")>

# %%
button = driver.find_element_by_xpath('//*[@id="load-more-trigger"]')

# %%
last_height = driver.execute_script("return document.body.scrollHeight")

# %%
from selenium.common.exceptions import ElementNotVisibleException

# %%
ElementNotVisibleException
# Out:
# selenium.common.exceptions.ElementNotVisibleException

# %%
for i in range(100):
    try:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        button.click()
    except ElementNotVisibleException:
        time.sleep(0.5)
        continue
    time.sleep(1.5)

# %% [markdown]
# Now that I've scraped the reviews, I can extract them from the html file using `BeautifulSoup`.

# %%
import os
from bs4 import BeautifulSoup

# %%
with open("../imdb/imdb_swtlj_reviews.html", 'r') as f:
    imdb_body = f.read()

# %%
imdb_soup = BeautifulSoup(imdb_body, "html5lib")

# %%
review_title = imdb_soup.find(text = 'Lived up to the hype, and in some places, beyond.')

# %%
reviews = imdb_soup.find_all("div", {'class': 'review-container'})

# %%
review = reviews[0]

# %%
# get user rating
imdb_rating = int(review.find("div", {'class': 'ipl-ratings-bar'}).find('span').find('span').text)
imdb_rating
# Out:
# 2

# %%
# get title
review.find("div", {'class': 'title'}).text
# Out:
# 'I remember when critics used to give bad reviews for mediocre scripts'

# %%
# get review date
review.find("span", {"class": 'review-date'}).text
# Out:
# '18 December 2017'

# %%
# user link
review.find("span", {'class': 'display-name-link'}).a['href']

# username
review.find("span", {'class': 'display-name-link'}).text
# Out:
# 'zparadigm'

# %%
# get review text
print(review.find('div', {'class': 'text'}).text)
# Out:
# Lazy story writing and more plot-holes than an average movie experience. I just don't see anything bold about this story. Lets see bad guys have new tech that has a single weakpoint? CheckDeath Star related weapon? CheckNew Heroes in safety bubble while everyone around them dies? CheckCute aliens to sell toys? CheckHoth like battle on sand instead of snow? CheckSpace chase like episode 5... well not as exciting but CheckOk now explain bombs that fall in space. Leia surviving space long enough to force pull back to the cruiser. Dj learning about the shuttles. Rose being portrayed as a strong female character, yet throws the survival of the resistance away for a fangirl love of Finn. Phasma was a complete waste.
# I enjoyed three moments in the film if I am being honest and the person next to me fell asleep in the middle and started snoring. When the movie ended no one clapped we all just sat there thinking WTF did we just watch.

# %%
import re

# %%
# get number of useful votes
useful_count, vote_count = re.findall("\d+", review.find("div", {'class': 'actions text-muted'}).text)

# %% [markdown]
# Cool, now I can wrap all of this together to build up the data I want.

# %%
reviews = imdb_soup.find_all("div", {'class': 'review-container'})

# %%
imdb_ratings = []
user_names = []
user_links = []
review_dates = []
review_text = []
upvotes = []
downvotes = []

skip_indexes = []
for i, review in enumerate(reviews):
    print("\rIteration %d out of %d" %(i+1, len(reviews)), end = "")
    
    try:
        # add user rating
        star_rating = review.find("div", {'class': 'ipl-ratings-bar'})
        if star_rating is None:
            imdb_ratings.append(star_rating)
        else:
            imdb_ratings.append(int(star_rating.find('span').find('span').text))
        
        # add username:
        user_names.append(review.find("span", {'class': 'display-name-link'}).text)

        # add user link:
        user_links.append(review.find("span", {'class': 'display-name-link'}).a['href'])

        # add review date:
        review_dates.append(review.find("span", {"class": 'review-date'}).text)

        # add review text:
        review_text.append(review.find('div', {'class': 'text'}).text)

        # vote counts
        upvote_count, total_count = re.findall("[0-9,]+", 
                                                  review.find("div", {'class': 'actions text-muted'}).text.replace(",", ""))

        # add upvote count:
        upvotes.append(upvote_count)
        downvotes.append(int(total_count) - int(upvote_count))
        
    except AttributeError:
        print("\rskipped %-100d" %i)
        skip_indexes.append(i)
# Out:
# Iteration 3683 out of 3683

# %%
import pandas as pd

# %%
imdb_data = pd.DataFrame(
    dict(
        imdb_ratings = imdb_ratings,
        user_names = user_names,
        user_links = user_links,
        review_dates = review_dates,
        review_text = review_text,
        upvotes = upvotes,
        downvotes = downvotes))

# %%
imdb_data
# Out:
#       downvotes  imdb_ratings      review_dates  \
# 0            62           2.0  18 December 2017
# 1            13           4.0  18 December 2017
# 2            56           1.0  20 December 2017
# 3             5           3.0  22 December 2017
# 4           135           4.0  16 December 2017
# 5           369           2.0  14 December 2017
# 6            20           1.0  24 December 2017
# 7           118           2.0  21 December 2017
# 8           106           1.0  17 December 2017
# 9            94           1.0  17 December 2017
# 10           43           1.0  16 December 2017
# 11          183           2.0  14 December 2017
# 12          268           1.0  15 December 2017
# 13          129           4.0  17 December 2017
# 14           80           1.0  16 December 2017
# 15           80           2.0  16 December 2017
# 16          190           3.0  14 December 2017
# 17          186           2.0  14 December 2017
# 18          134           1.0  16 December 2017
# 19          125           1.0  21 December 2017
# 20           79           2.0  16 December 2017
# 21           40           2.0  16 December 2017
# 22           21           3.0  16 December 2017
# 23          243           3.0  14 December 2017
# 24          142           3.0  15 December 2017
# 25           90           1.0  15 December 2017
# 26          209           3.0  14 December 2017
# 27            3           1.0  18 December 2017
# 28          421           4.0  14 December 2017
# 29          117           4.0  14 December 2017
# ...         ...           ...               ...
# 3653          6           7.0  14 December 2017
# 3654          3           7.0  14 December 2017
# 3655          6           7.0  14 December 2017
# 3656          9           8.0  14 December 2017
# 3657         12          10.0  14 December 2017
# 3658          8           7.0  14 December 2017
# 3659          5           NaN  14 December 2017
# 3660          9           8.0  14 December 2017
# 3661          9           8.0  14 December 2017
# 3662          9           8.0  14 December 2017
# 3663          9          10.0  14 December 2017
# 3664         11           9.0  14 December 2017
# 3665         12          10.0  14 December 2017
# 3666         10           9.0  14 December 2017
# 3667         11           8.0  14 December 2017
# 3668         13           9.0  14 December 2017
# 3669          8          10.0  14 December 2017
# 3670         11           9.0  14 December 2017
# 3671         12          10.0  14 December 2017
# 3672         12          10.0  14 December 2017
# 3673         11           8.0  14 December 2017
# 3674          7           8.0  13 December 2017
# 3675         20          10.0  14 December 2017
# 3676         10           7.0  13 December 2017
# 3677          6           6.0  13 December 2017
# 3678         12           8.0  13 December 2017
# 3679         10           8.0  13 December 2017
# 3680          9           8.0  13 December 2017
# 3681         10           9.0  13 December 2017
# 3682          8           5.0  13 December 2017
#
#                                             review_text upvotes  \
# 0     Lazy story writing and more plot-holes than an...     283
# 1     I've read articles saying the THE LAST JEDI is...      75
# 3679  http://www.imdb.com/user/ur68871048/?ref_=tt_urv
# 3680  http://www.imdb.com/user/ur83234735/?ref_=tt_urv
# 3681  http://www.imdb.com/user/ur40750786/?ref_=tt_urv
# 3682  http://www.imdb.com/user/ur49735864/?ref_=tt_urv
#
#                           user_names
# 0                          zparadigm
# 1                            zvelf-1
# 2                       jonmit-88269
# 3          gordonwright10-681-637828
# 4                           penny514
# 5                         gotton2013
# 6                         realmuthaf
# 7                         nadblaster
# 8                           tuanskie
# 9                       Marcus James
# 10                      mdyansufiyan
# 11                 emanueleromagnolo
# 12                             liell
# 13                       moviefan882
# 14                      outlaw-28563
# 15                   prev-455-773646
# 16                      samuel_faict
# 17                       prab-jhooti
# 18                 todoloquenotedije
# 19                        sixbells99
# 20                     nicholasciano
# 21                     Jesse-kononen
# 22                     mordauntdylan
# 23                      wolfybiscuts
# 24                         avamoreci
# 25                  sunnylight-73927
# 26                    Kevinlenaerts1
# 27                        mrbenflood
# 28                         MoodyHank
# 29                           corozin
# ...                              ...
# 3653                        OttoVonB
# 3654                  ioannisdassios
# 3655                           dfle3
# 3656                       densmolin
# 3657                   mobblesgaming
# 3658                          anhans
# 3659                            azwh
# 3660                 vincent_tillema
# 3661               jasoncurtis-00140
# 3662  My_name_is_Buck_and_Im_here_to
# 3663                   joshuastavers
# 3664                     Mitodru Roy
# 3665                   chrishayes737
# 3666                 augustoalvarezh
# 3667                  AntonioTavanti
# 3668                     gugabedicks
# 3669                   nicholasleezt
# 3670              andreisaniceperson
# 3671                        jojifrey
# 3672                     liverpudean
# 3673                      eve_dolluk
# 3674               rileyjamesherbert
# 3675                Jeanne Francoise
# 3676                       Andreas D
# 3677                    martnieuwhof
# 3678         joshuachristensen-57870
# 3679                    jamesleeryan
# 3680                        dylantey
# 3681                      theojclark
# 3682                    almazhafirap
#
# [3683 rows x 7 columns]

# %%
imdb_data.to_csv("../data/imdb_data.csv", index = None)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
(imdb_data.imdb_ratings
     .plot(kind = 'hist')
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-322-a83755e52dd6> in <module>()
#       1 (imdb_data.imdb_ratings
# ----> 2      .plot(kind = 'hist')
#       3 )
#
# ~\Anaconda3\envs\selenium-env\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2501                            colormap=colormap, table=table, yerr=yerr,
#    2502                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2503                            **kwds)
#    2504     __call__.__doc__ = plot_series.__doc__
#    2505
#
# ~\Anaconda3\envs\selenium-env\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1925                  yerr=yerr, xerr=xerr,
#    1926                  label=label, secondary_y=secondary_y,
# -> 1927                  **kwds)
#    1928
#    1929
#
# ~\Anaconda3\envs\selenium-env\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1725                             pass
#    1726                 data = series
# -> 1727         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1728
#    1729     plot_obj.generate()
#
# ~\Anaconda3\envs\selenium-env\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, bins, bottom, **kwargs)
#    1307         self.bottom = bottom
#    1308         # Do not call LinePlot.__init__ which may fill nan
# -> 1309         MPLPlot.__init__(self, data, **kwargs)
#    1310
#    1311     def _args_adjust(self):
#
# ~\Anaconda3\envs\selenium-env\lib\site-packages\pandas\plotting\_core.py in __init__(self, data, kind, by, subplots, sharex, sharey, use_index, figsize, grid, legend, rot, ax, fig, title, xlim, ylim, xticks, yticks, sort_columns, fontsize, secondary_y, colormap, table, layout, **kwds)
#      98                  table=False, layout=None, **kwds):
#      99
# --> 100         _converter._WARN = False
#     101         self.data = data
#     102         self.by = by
#
# NameError: name '_converter' is not defined
